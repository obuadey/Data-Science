# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AAPL-2017.csv', index_col='Date') #using pandas to read csv - mush simpler hehe
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.head() #printing the first 5 items
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  115.800003  116.330002  114.760002  116.150002  113.013916
# 2017-01-04  115.849998  116.510002  115.750000  116.019997  112.887413
# 2017-01-05  115.919998  116.860001  115.809998  116.610001  113.461502
# 2017-01-06  116.779999  118.160004  116.470001  117.910004  114.726402
# 2017-01-09  117.949997  119.430000  117.940002  118.989998  115.777237
#
#               Volume
# Date
# 2017-01-03  28781900
# 2017-01-04  21118100
# 2017-01-05  22193600
# 2017-01-06  31751900
# 2017-01-09  33561900

# %%
df2 = pd.read_csv('AAPL-2017.csv', usecols=['Date','Volume']) # specifying the columns we want to plot
df2.plot()

# %%
plt.show()  #Not really necessary, as earlier plot()
